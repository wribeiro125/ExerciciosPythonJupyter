# %% [markdown]
# # Exercícios de Estrutura De Repetição

# %%
# 1 - Faça um programa que peça uma nota, entre zero e dez. 
# Mostre uma mensagem caso o valor seja inválido e 
# continue pedindo até que o usuário informe um valor válido.

while(True):
    nota = float(input('Digite a nota: '))
    if (10 >= nota >= 0):
        print(f'Nota: {nota}')
        break;
    else:
        print('Digite uma nota válida!')
print('Fim')

# %%
while(True):
    usuario = input('Usuário: ')
    senha = input('Senha: ')
    if usuario != senha:
        print(f'Bem Vindo, {usuario}!')
        break;
    else:
        print('Usuario e senha iguais não são permitidos, digite novamente!')

# %%
# 3 - Faça um programa que leia e valide as seguintes informações:
# Nome: maior que 3 caracteres;
# Idade: entre 0 e 150;
# Salário: maior que zero;
# Sexo: 'f' ou 'm';
# Estado Civil: 's', 'c', 'v', 'd';

while(True):
    nome = input('Digite seu nome: ')
    tamanhonome = len(nome)
    if tamanhonome > 3:
        break
    else:
        print('Nome inválido.')
while(True):
    idade = int(input('Digite sua idade: '))                
    if 150 >= idade >= 0:
        break
    else:
        print('Idade inválida, digite novamente!')
while(True):
    salario = float(input('Digite seu salário: '))
    if salario > 0:
        break
    else:
        print('Salário inválido, digite novamente!')
while(True):
    sexo = input('Digite seu sexo [m - masculino / f - feminino]: ').lower()
    if sexo in 'fm':
        break
    else:
        print('Sexo inválido, digite novamente!')
while(True):
    estado_civil = input('Digite seu estado civil [s - solteiro(a)/ c - casado(a)/ v - viúvo(a)/ d - divorciado(a)]').lower()
    if estado_civil in 'scvd':
        break
    else:
        print('Estado Civil inválido, digite novamente!')
print(f'\nNome: {nome} \nIdade: {idade} \nSalário: R${salario:.2f} \nSexo: {sexo.upper()} \nEstado Civil: {estado_civil.upper()} ')

# %%
# 4 - Supondo que a população de um país A seja da ordem de 80000 habitantes com uma taxa anual de crescimento de 3% 
# e que a população de B seja 200000 habitantes com uma taxa de crescimento de 1.5%. 
# Faça um programa que calcule e escreva o número de anos necessários para que a população 
# do país A ultrapasse ou iguale a população do país B, mantidas as taxas de crescimento.


#verificar dps
a = 80000
b = 200000
anos = 0
crescimentoA = a * 0.03 #2400
crescimentoB = b * 0.015 #3000
while(a < b):
    a = a + (a * 0.03)
    #print(f'A: {a}')
    b = b + (b * 0.015)
    #print(f'B: {b}\n')
    anos += 1

print(f'População A: {a}')
print(f'População B: {b}')
print(f'Anos: {anos}')

# %%
# 6 - Faça um programa que imprima na tela os números de 1 a 20, um abaixo do outro. 
# Depois modifique o programa para que ele mostre os números um ao lado do outro.

for i in range(1, 21):
    print(i, end = ' ')

# %%
# 7 - Faça um programa que leia 5 números e informe o maior número.
maior = 0
for i in range(0, 5):
    num = int(input(f'{i+1}º número: '))
    if num > maior:
        maior = num
print(f'O maior é: {maior}')

# %%
# 8 - Faça um programa que leia 5 números e informe a soma e a média dos números.

soma = 0
media = 0

for i in range(0, 5):
    num = int(input(f'{i+1}º número: '))
    soma += num
media = soma/5
print(f'Soma: {soma} \nMédia: {media}')

# %%
# 9 - Faça um programa que imprima na tela apenas os números ímpares entre 1 e 50.

for i in range(1, 51):
    if i%2 != 0:
        print(i, end = ' ')

# %%
# 10 - Faça um programa que receba dois números inteiros e 
# gere os números inteiros que estão no intervalo compreendido por eles.
maior = 0
menor = 0
num1 = int(input('Primeiro número: '))
num2 = int(input('Segundo número: '))
if num1 > num2: 
    maior = num1
    menor = num2
else:
    maior = num2
    menor = num1
for i in range(menor+1, maior):
    print(i, end = ' ')

# %%
# 11 - Altere o programa anterior para mostrar no final a soma dos números.
maior = 0
menor = 0
soma = 0
num1 = int(input('Primeiro número: '))
num2 = int(input('Segundo número: '))
if num1 > num2: 
    maior = num1
    menor = num2
else:
    maior = num2
    menor = num1
for i in range(menor+1, maior):
    soma += i
    print(i)
print('___')
print(soma)

# %%
# 12 - Desenvolva um gerador de tabuada, capaz de gerar a tabuada de qualquer 
# número inteiro entre 1 a 10. O usuário deve informar de qual numero ele deseja ver a tabuada. 
# A saída deve ser conforme o exemplo abaixo:
# Tabuada de 5:
# 5 X 1 = 5
# 5 X 2 = 10
# ...
# 5 X 10 = 50

numero = int(input('Digite o número: '))
for i in range(0, 11):
    print(f'{i} x {numero} = {i * numero}')

# %%
# 14 - Faça um programa que peça 10 números inteiros, calcule e 
# mostre a quantidade de números pares e a quantidade de números impares.
pares = 0
impares = 0
for i in range(0, 10):
    if i%2 == 0:
        pares += 1
    else:
        impares += 1
print(f'Pares: {pares} \nImpares: {impares}')

# %%
# 18 - Faça um programa que, dado um conjunto de N números, 
# determine o menor valor, o maior valor e a soma dos valores.
menor = 0
maior = 0
soma = 0
verifica = 's'
while(True):
    numero = int(input('Digite o número: '))
    if numero > maior:
        maior = numero
    else:
        menor = numero
    soma += numero
    verifica = input('Deseja continuar? [S/N]: ').lower()
    if verifica == 'n':
        break
print(f'Maior: {maior} \nMenor: {menor} \nSoma: {soma}')

# %%
# 19 - Faça um programa que calcule o mostre a média aritmética de N notas.
cont = 0
total = 0
media = 0
while(True):
    nota = float(input('Digite sua nota: '))
    cont += 1
    total += nota
    verif = input('Deseja continuar?').lower()
    if verif == 'n':
        break
media = total/cont
print(f'Média: {media:.1f}')

# %%
# 25 - Faça um programa que peça para n pessoas a sua idade, ao final 
# o programa devera verificar se a média de idade da turma varia entre 0 e 25,26 e 60 e maior que 60; 
# e então, dizer se a turma é jovem, adulta ou idosa, conforme a média calculada.
verifica = True
cont = 0
soma = 0
media = 0
while(verifica):
    idade = int(input('Digite a idade: '))
    soma += idade
    cont += 1
    opc = input('Continua? [s/n]: ').lower()
    if opc == 'n':
        verifica = False
media = round(soma/cont)

if 25 >= media > 0:
    print('Turma jovem')
elif 60 >= media > 25:
    print('Turma adulta')
else:
    print('Turma idosa')

# %%
# 26 - Numa eleição existem três candidatos. Faça um programa que peça o número total de eleitores. 
# Peça para cada eleitor votar e ao final mostrar o número de votos de cada candidato.

candidato1 = 0
candidato2 = 0
candidato3 = 0
nulo = 0
total_eleitores = int(input('Total de eleitores: '))
print('Candidato 1: [19] \nCandidato 2: [55] \nCandidato 3: [70]')
for i in range(0, total_eleitores):    
    voto = int(input('Digite seu voto: '))
    if voto == 19:
        candidato1 += 1
    elif voto == 55:
        candidato2 += 1
    elif voto == 70:
        candidato3 += 1
    else:
        nulo += 1
print('')
print('Total de Votos:\n')
print('-'*10)
print(f'Candidato 1: {candidato1}')
print(f'Candidato 2: {candidato2}')
print(f'Candidato 3: {candidato3}')
print(f'Nulos: {nulo}')
print('-'*10)

# %%
# 27 - Faça um programa que calcule o número médio de alunos por turma. 
# Para isto, peça a quantidade de turmas e a quantidade de alunos para cada turma. 
# As turmas não podem ter mais de 40 alunos.

total_turmas = 0
total_alunos = 0
media_alunos = 0
while(True):
    alunos = int(input('Digite a quantidade de alunos: '))
    if alunos > 40:
        print('A turma não pode ter mais de 40 alunos!')
    else:
        total_alunos += alunos
        total_turmas +=1
        verifica = input('Deseja continuar?[s/n]: ').lower()
        if verifica == 'n':
            break
media_alunos = round(total_alunos/total_turmas)
print(f'Média de alunos por turma: {media_alunos}')

# %%
# 28 - Faça um programa que calcule o valor total investido por um colecionador em sua 
# coleção de CDs e o valor médio gasto em cada um deles. O usuário deverá informar 
# a quantidade de CDs e o valor para em cada um.

valor_total = 0
valor_medio = 0

cds = int(input("Quantidade de CD's: "))
for i in range(0, cds):
    valor = float(input(f'Valor do {i+1}º: '))
    valor_total += valor
valor_medio = valor_total/cds
print(f'\nValor Total: R${valor_total:.2f}')
print(f'Valor Médio: R${valor_medio:.2f}')

# %%
# 30 - O Sr. Manoel Joaquim acaba de adquirir uma panificadora e pretende implantar 
# a metodologia da tabelinha, que já é um sucesso na sua loja de 1,99. 
# Você foi contratado para desenvolver o programa que monta a tabela de preços de pães, 
# de 1 até 50 pães, a partir do preço do pão informado pelo usuário, conforme o exemplo abaixo:
# Preço do pão: R$ 0.18
# Panificadora Pão de Ontem - Tabela de preços
# 1 - R$ 0.18
# 2 - R$ 0.36
# ...
# 50 - R$ 9.00

preco_pao = 0.18
print('-*-' * 15)
print('Tabela de Preços:\n')
for i in range(1, 51):
    print(f'{i} - R${preco_pao * i:.2f}')
print('-*-' * 15)

# %%
"""
31 - O Sr. Manoel Joaquim expandiu seus negócios para além dos negócios de 1,99 
e agora possui uma loja de conveniências. Faça um programa que implemente uma 
caixa registradora rudimentar. O programa deverá receber um número desconhecido de valores 
referentes aos preços das mercadorias. Um valor zero deve ser informado pelo operador para 
indicar o final da compra. 
O programa deve então mostrar o total da compra e perguntar o valor em dinheiro que 
o cliente forneceu, 
para então calcular e mostrar o valor do troco. 
Após esta operação, o programa deverá voltar ao ponto inicial, para registrar a próxima compra. 
A saída deve ser conforme o exemplo abaixo:

Lojas Tabajara 
Produto 1: R$ 2.20
Produto 2: R$ 5.80
Produto 3: R$ 0
Total: R$ 9.00
Dinheiro: R$ 20.00
Troco: R$ 11.00
"""

preco = -1
total_compra = 0
troco = 0
cont = 0
while(True):
    while(preco != 0): #Finalizar a compra
        preco = float(input('Preço: R$'))
        total_compra += preco
        cont += 1
        if preco == 0:
            print(f'Total a pagar: R$ {total_compra:.2f}')
            pagamento = float(input('Pagamento: R$')) #Valor que o cliente vai dar para pagar
            troco = pagamento - total_compra
            print('')
            print('-' * 10)
            print('Lojas Tabajara')
            print(f'Total: R$ {total_compra:.2f}')
            print(f'Dinheiro: R$ {pagamento:.2f}')
            print(f'Troco: {troco:.2f}')
            print('-' * 10)
            preco = -1
            total_compra = 0
# Out:
# Preço: R$f
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-7fb8c7f9c5be> in <module>
#      26 while(True):
#      27     while(preco != 0): #Finalizar a compra
# ---> 28         preco = float(input('Preço: R$'))
#      29         total_compra += preco
#      30         cont += 1
#
# ValueError: could not convert string to float: 'f'
